# %%
import timeit
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from timeit import Timer

# %%
def basic(x, y, n):
    if (n == 1):
        return x * y

    m = n / 2
    a = x / pow(2, m)
    b = x % pow(2, m)
    c = y / pow(2, m)
    d = y % pow(2, m)
    e = basic(a, c, m)
    f = basic(b, d, m)
    g = basic(b, c, m)
    h = basic(a, d, m)

    return (pow(2, 2 * m) * e) + (pow(2, m) * (g + h)) + f

def karatsuba(x, y, n):
    if (n == 1):
        return x * y
    
    m = n / 2
    a = x / pow(2, m)
    b = x % pow(2, m)
    c = y / pow(2, m)
    d = y % pow(2, m)
    e = karatsuba(a, c, m)
    f = karatsuba(b, d, m)
    g = karatsuba(abs(a - b), abs(c - d), m)
    
    return (pow(2, 2 * m) * e) + (pow(2, m) * (e + f - g)) + f

# %%
tb = []
td = []
tk = []
    
for i in range(10, 100):
    r = pow(i, 2)
    l = len(str(abs(r)))
    
    x = pow(r, r)
    y = pow(r, r)
    
    rb = Timer(lambda: x * y)
    tb.append(rb.timeit(number=1))

    rd = Timer(lambda: basic(x, y, l))
    td.append(rd.timeit(number=1))

    rk = Timer(lambda: karatsuba(x, y, l))
    tk.append(rb.timeit(number=1))

# %%
# print("Average (BAS): " + str(np.average(tb)))
print("Average (D&C): " + str(np.average(td)))
print("Average (KAR): " + str(np.average(tk)))
# Out:
# Average (D&C): 0.00142174826728
# Average (KAR): 0.00110523435805

# %%
# plt.plot(tb, label="Basic")
plt.plot(td, label="Divide & Conquer")
plt.plot(tk, label="Karatsuba")
plt.legend(loc='lower left')
plt.title('Execution Time')
plt.xlabel('Execution #')
plt.ylabel('Time')
plt.show()
